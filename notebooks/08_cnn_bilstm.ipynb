# %% [markdown]
# # 08. Proposed Hybrid CNN + BiLSTM Deep Learning Model
# **ML-Powered Intrusion Detection System (IDS) for Secure Network Monitoring**
#
# This notebook implements, trains, and evaluates the **proposed primary model** of the project: the **Hybrid 1D-CNN + BiLSTM** network.
# - **1D-CNN layer:** Extracts local cross-feature representations from adjacent attributes in the flow vector.
# - **BiLSTM layer:** Models bidirectional contextual dependencies across the feature sequence.
# - **Dense head:** Performs non-linear classification across benign and attack traffic categories.

# %% [markdown]
# ## 1. Imports & Environment Setup

# %%
import sys
import json
import time
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score

# Ensure project root is in sys.path
ROOT_DIR = Path("..").resolve()
if str(ROOT_DIR) not in sys.path:
    sys.path.insert(0, str(ROOT_DIR))

from src.models.cnn_bilstm import CNNBiLSTMModel
from src.preprocessing.verify_split import load_partition

PROCESSED_DIR = ROOT_DIR / "data" / "processed"
MODELS_DIR = ROOT_DIR / "models" / "cnn_bilstm"
METRICS_DIR = ROOT_DIR / "results" / "metrics"
GRAPHS_DIR = ROOT_DIR / "results" / "graphs"
CONF_DIR = ROOT_DIR / "results" / "confusion_matrices"

# %% [markdown]
# ## 2. Dataset Loading

# %%
try:
    X_train, y_train = load_partition(PROCESSED_DIR / "train", "train")
    X_val, y_val = load_partition(PROCESSED_DIR / "validation", "val")
    X_test, y_test = load_partition(PROCESSED_DIR / "test", "test")
    
    mapping_file = PROCESSED_DIR / "label_mapping.json"
    label_mapping = {}
    if mapping_file.exists():
        with open(mapping_file, "r", encoding="utf-8") as f:
            label_mapping = json.load(f)
    inv_mapping = {v: k for k, v in label_mapping.items()}
    target_names = [inv_mapping.get(i, f"Class_{i}") for i in sorted(np.unique(y_train))]
    
    print(f"Loaded Partitions Successfully:")
    print(f"  X_train: {X_train.shape}, y_train: {y_train.shape}")
    print(f"  X_val:   {X_val.shape}, y_val:   {y_val.shape}")
    print(f"  X_test:  {X_test.shape}, y_test:  {y_test.shape}")
    print(f"  Number of Classes: {len(target_names)}")
except FileNotFoundError:
    print("Processed dataset partitions not found. Execute preprocessing pipeline on raw data in data/raw/.")

# %% [markdown]
# ## 3. Dataset Representation & Sequence Input Preparation
# The dataset consists of standardized tabular statistical flow features.
# We reshape the 2D feature matrix `(samples, features)` into `(samples, features, 1)` to pass through Conv1D feature extractors and BiLSTM recurrence.

# %%
if 'X_train' in locals():
    num_features = X_train.shape[1]
    num_classes = len(target_names)
    
    X_train_seq = np.expand_dims(X_train, axis=-1) if X_train.ndim == 2 else X_train
    X_val_seq = np.expand_dims(X_val, axis=-1) if X_val.ndim == 2 else X_val
    X_test_seq = np.expand_dims(X_test, axis=-1) if X_test.ndim == 2 else X_test
    
    print(f"Prepared Hybrid Input Tensors:")
    print(f"  X_train_seq: {X_train_seq.shape}")
    print(f"  X_val_seq:   {X_val_seq.shape}")
    print(f"  X_test_seq:  {X_test_seq.shape}")

# %% [markdown]
# ## 4. Class Distribution Analysis

# %%
if 'y_train' in locals():
    train_counts = pd.Series(y_train).value_counts().sort_index()
    train_dist = pd.DataFrame({
        "Class_Index": train_counts.index,
        "Class_Name": [inv_mapping.get(i, f"Class_{i}") for i in train_counts.index],
        "Train_Samples": train_counts.values,
        "Percentage": (train_counts.values / len(y_train)) * 100
    })
    display(train_dist)

# %% [markdown]
# ## 5. Proposed Hybrid CNN + BiLSTM Architecture Construction & Model Summary

# %%
if 'num_features' in locals():
    hybrid_model = CNNBiLSTMModel(
        num_features=num_features,
        num_classes=num_classes,
        conv_filters=64,
        kernel_size=3,
        lstm_units=64,
        dense_units=64,
        dropout_rate=0.3,
        learning_rate=0.001,
    )
    keras_hybrid = hybrid_model.build_model()
    keras_hybrid.summary()

# %% [markdown]
# ## 6. Model Training & Callbacks

# %%
if 'keras_hybrid' in locals() and 'X_train' in locals():
    import tensorflow as tf
    
    MODELS_DIR.mkdir(parents=True, exist_ok=True)
    checkpoint_path = MODELS_DIR / "best_model.keras"
    
    callbacks = [
        tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True),
        tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=2, min_lr=1e-6, verbose=1),
        tf.keras.callbacks.ModelCheckpoint(filepath=str(checkpoint_path), monitor="val_loss", save_best_only=True, verbose=1),
    ]
    
    print("Training Proposed Hybrid CNN + BiLSTM on X_train, y_train...")
    t0 = time.time()
    history = hybrid_model.fit(
        X_train=X_train,
        y_train=y_train,
        X_val=X_val,
        y_val=y_val,
        epochs=30,
        batch_size=128,
        callbacks_list=callbacks,
    )
    t_train = time.time() - t0
    print(f"Proposed Hybrid Training completed in {t_train:.2f} seconds.")

# %% [markdown]
# ## 7. Training & Validation Curves

# %%
if 'history' in locals():
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    
    # Loss Curve
    axes[0].plot(history.history['loss'], label='Train Loss', color='#2b5c8f', lw=2)
    axes[0].plot(history.history['val_loss'], label='Val Loss', color='#e27c3e', lw=2)
    axes[0].set_title('Proposed CNN + BiLSTM — Loss Trajectory')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)
    
    # Accuracy Curve
    axes[1].plot(history.history['accuracy'], label='Train Accuracy', color='#2b5c8f', lw=2)
    axes[1].plot(history.history['val_accuracy'], label='Val Accuracy', color='#3ca35d', lw=2)
    axes[1].set_title('Proposed CNN + BiLSTM — Accuracy Trajectory')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Accuracy')
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 8. Validation Set Evaluation

# %%
if 'hybrid_model' in locals() and hybrid_model.model is not None:
    y_val_pred = hybrid_model.predict(X_val)
    val_acc = accuracy_score(y_val, y_val_pred)
    val_f1_w = f1_score(y_val, y_val_pred, average='weighted', zero_division=0)
    val_f1_m = f1_score(y_val, y_val_pred, average='macro', zero_division=0)
    
    print(f"Validation Set Metrics:")
    print(f"  Accuracy:    {val_acc*100:.2f}%")
    print(f"  Weighted F1: {val_f1_w:.4f}")
    print(f"  Macro F1:    {val_f1_m:.4f}")

# %% [markdown]
# ## 9. Final Test Set Evaluation

# %%
if 'hybrid_model' in locals() and hybrid_model.model is not None:
    y_test_pred = hybrid_model.predict(X_test)
    test_acc = accuracy_score(y_test, y_test_pred)
    test_f1_w = f1_score(y_test, y_test_pred, average='weighted', zero_division=0)
    test_f1_m = f1_score(y_test, y_test_pred, average='macro', zero_division=0)
    
    print(f"Final Test Set Metrics (Unbiased Single Evaluation):")
    print(f"  Accuracy:    {test_acc*100:.2f}%")
    print(f"  Weighted F1: {test_f1_w:.4f}")
    print(f"  Macro F1:    {test_f1_m:.4f}")

# %% [markdown]
# ## 10. Test Confusion Matrix

# %%
if 'y_test_pred' in locals():
    cm = confusion_matrix(y_test, y_test_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='magma', xticklabels=target_names, yticklabels=target_names)
    plt.title('Proposed CNN + BiLSTM — Test Set Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 11. Per-Class Performance Metrics

# %%
if 'y_test_pred' in locals():
    report_dict = classification_report(y_test, y_test_pred, target_names=target_names, output_dict=True, zero_division=0)
    report_df = pd.DataFrame(report_dict).transpose()
    display(report_df)

# %% [markdown]
# ## 12. Misclassification & Error Analysis

# %%
if 'y_test_pred' in locals():
    err_idx = np.where(y_test != y_test_pred)[0]
    print(f"Total Misclassified Samples: {len(err_idx)} ({len(err_idx)/len(y_test)*100:.2f}% error rate)")
    
    err_df = pd.DataFrame({
        "Sample_Idx": err_idx,
        "True_Class": [inv_mapping.get(y_test[i], str(y_test[i])) for i in err_idx],
        "Predicted_Class": [inv_mapping.get(y_test_pred[i], str(y_test_pred[i])) for i in err_idx],
    })
    display(err_df.head(15))

# %% [markdown]
# ## 13. Comprehensive Benchmark Comparison (RF vs. XGBoost vs. 1D-CNN vs. BiLSTM vs. Proposed Hybrid)

# %%
comp_file = METRICS_DIR / "model_comparison.csv"
if comp_file.exists():
    comp_df = pd.read_csv(comp_file)
    display(comp_df)
else:
    print("Standard comparison table not yet available.")
    
ext_file = METRICS_DIR / "model_comparison_extended.csv"
if ext_file.exists():
    ext_df = pd.read_csv(ext_file)
    display(ext_df)
